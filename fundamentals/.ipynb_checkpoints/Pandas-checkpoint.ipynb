# %% [markdown]
# # Pandas fundamentals

# %% [markdown]
# This notebook demonstrates some of the features available in Pandas

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/henrique/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# ## Creating a data structure

# %%
# Create an array with 100 data points distributed along 20 rows and 5 columns
dataset = np.random.randint(0, 100, size=(20, 5))

# %% [markdown]
# ## Loading the Dataframe

# %%
# Create a dataframe with a numpy array with 100 entries
df = pd.DataFrame(dataset, columns=['Random 1', 'Random 2', 'Random 3', 'Random 4', 'Random 5'])

# %% [markdown]
# ## Manipulation

# %%
# Check the first 5 entries
df.head()
# Out:
#    Random 1  Random 2  Random 3  Random 4  Random 5
# 0        77        51        54        37        90
# 1        79        36        69        64        89
# 2        24        70        42        72        80
# 3        41        23        20        96        35
# 4        79        10        82        75        81

# %%
# Describe statistical properties
df.describe()
# Out:
#         Random 1   Random 2   Random 3   Random 4   Random 5
# count  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   53.850000  49.100000  53.800000  59.500000  51.050000
# std    27.394342  31.555965  32.949084  28.429969  25.834443
# min     6.000000   3.000000   4.000000   9.000000  13.000000
# 25%    32.000000  20.500000  22.250000  40.000000  30.250000
# 50%    61.500000  49.500000  57.000000  64.500000  48.500000
# 75%    73.250000  80.250000  82.750000  77.250000  77.000000
# max    98.000000  90.000000  97.000000  97.000000  90.000000

# %%
# Describe the datatype of each column and the total number of entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
# Random 1    20 non-null int64
# Random 2    20 non-null int64
# Random 3    20 non-null int64
# Random 4    20 non-null int64
# Random 5    20 non-null int64
# dtypes: int64(5)
# memory usage: 880.0 bytes

# %%
# Create a range of dates to use as index on the Dataframe
dates = pd.date_range('20180101', periods=20)

# %%
# Set a unique index for each line based on a date
df.index = dates

# %%
# Check the last 5 entries on the Dataframe
df.tail()
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5
# 2018-01-16        72        81        23        11        63
# 2018-01-17        24        80        12        64        62
# 2018-01-18        64        86        94        41        22
# 2018-01-19        97        19        85        93        43
# 2018-01-20        33        71        75        97        23

# %%
# Show the names of the columns
df.columns
# Out:
# Index(['Random 1', 'Random 2', 'Random 3', 'Random 4', 'Random 5'], dtype='object')

# %%
# Show the indexes
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10', '2018-01-11', '2018-01-12',
#                '2018-01-13', '2018-01-14', '2018-01-15', '2018-01-16',
#                '2018-01-17', '2018-01-18', '2018-01-19', '2018-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Show the values stored in the Dataframe
df.values
# Out:
# array([[77, 51, 54, 37, 90],
#        [79, 36, 69, 64, 89],
#        [24, 70, 42, 72, 80],
#        [41, 23, 20, 96, 35],
#        [79, 10, 82, 75, 81],
#        [51,  9,  5,  9, 32],
#        [ 6, 48, 60, 27, 80],
#        [37,  3, 86, 65, 32],
#        [ 8, 21, 97, 84, 25],
#        [98, 73, 36, 90, 50],
#        [72, 82, 97, 75, 13],
#        [63, 87, 14, 45, 63],
#        [61,  5,  4, 15, 15],
#        [62, 37, 82, 75, 76],
#        [29, 90, 39, 55, 47],
#        [72, 81, 23, 11, 63],
#        [24, 80, 12, 64, 62],
#        [64, 86, 94, 41, 22],
#        [97, 19, 85, 93, 43],
#        [33, 71, 75, 97, 23]])

# %%
# Sort by index descending
df.sort_index(axis=0, ascending=False).head()
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5
# 2018-01-20        33        71        75        97        23
# 2018-01-19        97        19        85        93        43
# 2018-01-18        64        86        94        41        22
# 2018-01-17        24        80        12        64        62
# 2018-01-16        72        81        23        11        63

# %%
# Sort by value descending
df.sort_values(by='Random 2', ascending=False).head()
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5
# 2018-01-15        29        90        39        55        47
# 2018-01-12        63        87        14        45        63
# 2018-01-18        64        86        94        41        22
# 2018-01-11        72        82        97        75        13
# 2018-01-16        72        81        23        11        63

# %%
# Extract a Series from the Dataframe
df['Random 1']
# Out:
# 2018-01-01    77
# 2018-01-02    79
# 2018-01-03    24
# 2018-01-04    41
# 2018-01-05    79
# 2018-01-06    51
# 2018-01-07     6
# 2018-01-08    37
# 2018-01-09     8
# 2018-01-10    98
# 2018-01-11    72
# 2018-01-12    63
# 2018-01-13    61
# 2018-01-14    62
# 2018-01-15    29
# 2018-01-16    72
# 2018-01-17    24
# 2018-01-18    64
# 2018-01-19    97
# 2018-01-20    33
# Freq: D, Name: Random 1, dtype: int64

# %%
# Select the first 10 days
df['20180101':'20180110']
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5
# 2018-01-01        77        51        54        37        90
# 2018-01-02        79        36        69        64        89
# 2018-01-03        24        70        42        72        80
# 2018-01-04        41        23        20        96        35
# 2018-01-05        79        10        82        75        81
# 2018-01-06        51         9         5         9        32
# 2018-01-07         6        48        60        27        80
# 2018-01-08        37         3        86        65        32
# 2018-01-09         8        21        97        84        25
# 2018-01-10        98        73        36        90        50

# %%
# Select all data on index 0 (the first date)
df.loc['20180101']
# Out:
# Random 1    77
# Random 2    51
# Random 3    54
# Random 4    37
# Random 5    90
# Name: 2018-01-01 00:00:00, dtype: int64

# %%
# Select all data on the first 2 columns
df.loc[:,['Random 1', 'Random 2']].head()
# Out:
#             Random 1  Random 2
# 2018-01-01        77        51
# 2018-01-02        79        36
# 2018-01-03        24        70
# 2018-01-04        41        23
# 2018-01-05        79        10

# %%
# Select the first line by position
df.iloc[0]
# Out:
# Random 1    77
# Random 2    51
# Random 3    54
# Random 4    37
# Random 5    90
# Name: 2018-01-01 00:00:00, dtype: int64

# %%
# Select the first 5 rows and third column
df.iloc[:5,2:3]
# Out:
#             Random 3
# 2018-01-01        54
# 2018-01-02        69
# 2018-01-03        42
# 2018-01-04        20
# 2018-01-05        82

# %%
# Select values based on boolean condition
df[df['Random 1'] > 50]
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5
# 2018-01-01        77        51        54        37        90
# 2018-01-02        79        36        69        64        89
# 2018-01-05        79        10        82        75        81
# 2018-01-06        51         9         5         9        32
# 2018-01-10        98        73        36        90        50
# 2018-01-11        72        82        97        75        13
# 2018-01-12        63        87        14        45        63
# 2018-01-13        61         5         4        15        15
# 2018-01-14        62        37        82        75        76
# 2018-01-16        72        81        23        11        63
# 2018-01-18        64        86        94        41        22
# 2018-01-19        97        19        85        93        43

# %%
# Create a new Series object to add a column on the Dataframe. Indexes must match
new_column = pd.Series(np.arange(20), index=pd.date_range('20180101', periods=20))

# %%
# Add new column to Dataframe
df['Arange'] = new_column

# %%
# Check the new column
df.head()
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange
# 2018-01-01        77        51        54        37        90       0
# 2018-01-02        79        36        69        64        89       1
# 2018-01-03        24        70        42        72        80       2
# 2018-01-04        41        23        20        96        35       3
# 2018-01-05        79        10        82        75        81       4

# %%
# Create empty list
date_names = []

# %%
# Populate the list with dates
for i, x in enumerate(range(1,21)):
    date_names.append('January ' + str(x))

# %%
# Create a Series object
new_column = pd.Series(date_names, index=pd.date_range('20180101', periods=20))

# %%
# Add a column to the Dataframe
df['Date'] = new_column

# %%
# Check the new added column
df.head()
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
# 2018-01-01        77        51        54        37        90       0
# 2018-01-02        79        36        69        64        89       1
# 2018-01-03        24        70        42        72        80       2
# 2018-01-04        41        23        20        96        35       3
# 2018-01-05        79        10        82        75        81       4
#
#                  Date
# 2018-01-01  January 1
# 2018-01-02  January 2
# 2018-01-03  January 3
# 2018-01-04  January 4
# 2018-01-05  January 5

# %%
# Apply custom function along the columns
df.iloc[:,:5].apply(np.sum)
# Out:
# Random 1    1077
# Random 2     982
# Random 3    1076
# Random 4    1190
# Random 5    1021
# dtype: int64

# %%
# Fill some values with nan
df.iloc[[2, 6, 7], [2, 3]] = np.NaN

# %%
# Drop any rows with empty data
df.dropna(how='any')
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
# 2018-01-01        77        51      54.0      37.0        90       0
# 2018-01-02        79        36      69.0      64.0        89       1
# 2018-01-04        41        23      20.0      96.0        35       3
# 2018-01-05        79        10      82.0      75.0        81       4
# 2018-01-06        51         9       5.0       9.0        32       5
# 2018-01-09         8        21      97.0      84.0        25       8
# 2018-01-10        98        73      36.0      90.0        50       9
# 2018-01-11        72        82      97.0      75.0        13      10
# 2018-01-12        63        87      14.0      45.0        63      11
# 2018-01-13        61         5       4.0      15.0        15      12
# 2018-01-14        62        37      82.0      75.0        76      13
# 2018-01-15        29        90      39.0      55.0        47      14
# 2018-01-16        72        81      23.0      11.0        63      15
# 2018-01-17        24        80      12.0      64.0        62      16
# 2018-01-18        64        86      94.0      41.0        22      17
# 2018-01-19        97        19      85.0      93.0        43      18
# 2018-01-20        33        71      75.0      97.0        23      19
#
#                   Date
# 2018-01-01   January 1
# 2018-01-02   January 2
# 2018-01-04   January 4
# 2018-01-05   January 5
# 2018-01-06   January 6
# 2018-01-09   January 9
# 2018-01-10  January 10
# 2018-01-11  January 11
# 2018-01-12  January 12
# 2018-01-13  January 13
# 2018-01-14  January 14
# 2018-01-15  January 15
# 2018-01-16  January 16
# 2018-01-17  January 17
# 2018-01-18  January 18
# 2018-01-19  January 19
# 2018-01-20  January 20

# %%
# Fill empty data with 10
df.fillna(value=10)
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
# 2018-01-01        77        51      54.0      37.0        90       0
# 2018-01-02        79        36      69.0      64.0        89       1
# 2018-01-03        24        70      10.0      10.0        80       2
# 2018-01-04        41        23      20.0      96.0        35       3
# 2018-01-05        79        10      82.0      75.0        81       4
# 2018-01-06        51         9       5.0       9.0        32       5
# 2018-01-07         6        48      10.0      10.0        80       6
# 2018-01-08        37         3      10.0      10.0        32       7
# 2018-01-09         8        21      97.0      84.0        25       8
# 2018-01-10        98        73      36.0      90.0        50       9
# 2018-01-11        72        82      97.0      75.0        13      10
# 2018-01-12        63        87      14.0      45.0        63      11
# 2018-01-13        61         5       4.0      15.0        15      12
# 2018-01-14        62        37      82.0      75.0        76      13
# 2018-01-15        29        90      39.0      55.0        47      14
# 2018-01-16        72        81      23.0      11.0        63      15
# 2018-01-17        24        80      12.0      64.0        62      16
# 2018-01-18        64        86      94.0      41.0        22      17
# 2018-01-19        97        19      85.0      93.0        43      18
# 2018-01-20        33        71      75.0      97.0        23      19
#
#                   Date
# 2018-01-01   January 1
# 2018-01-02   January 2
# 2018-01-03   January 3
# 2018-01-04   January 4
# 2018-01-05   January 5
# 2018-01-06   January 6
# 2018-01-07   January 7
# 2018-01-08   January 8
# 2018-01-09   January 9
# 2018-01-10  January 10
# 2018-01-11  January 11
# 2018-01-12  January 12
# 2018-01-13  January 13
# 2018-01-14  January 14
# 2018-01-15  January 15
# 2018-01-16  January 16
# 2018-01-17  January 17
# 2018-01-18  January 18
# 2018-01-19  January 19
# 2018-01-20  January 20

# %%
# Mean value for each column
df.mean()
# Out:
# Random 1    53.850000
# Random 2    49.100000
# Random 3    52.235294
# Random 4    60.352941
# Random 5    51.050000
# Arange       9.500000
# dtype: float64

# %%
# Mean value of rows
df.mean(1)
# Out:
# 2018-01-01    51.500000
# 2018-01-02    56.333333
# 2018-01-03    44.000000
# 2018-01-04    36.333333
# 2018-01-05    55.166667
# 2018-01-06    18.500000
# 2018-01-07    35.000000
# 2018-01-08    19.750000
# 2018-01-09    40.500000
# 2018-01-10    59.333333
# 2018-01-11    58.166667
# 2018-01-12    47.166667
# 2018-01-13    18.666667
# 2018-01-14    57.500000
# 2018-01-15    45.666667
# 2018-01-16    44.166667
# 2018-01-17    43.000000
# 2018-01-18    54.000000
# 2018-01-19    59.166667
# 2018-01-20    53.000000
# Freq: D, dtype: float64

# %%
# Shift the first 10 rows
df.shift(10)
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
# 2018-01-01       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-02       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-03       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-04       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-05       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-06       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-07       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-08       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-09       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-10       NaN       NaN       NaN       NaN       NaN     NaN
# 2018-01-11      77.0      51.0      54.0      37.0      90.0     0.0
# 2018-01-12      79.0      36.0      69.0      64.0      89.0     1.0
# 2018-01-13      24.0      70.0       NaN       NaN      80.0     2.0
# 2018-01-14      41.0      23.0      20.0      96.0      35.0     3.0
# 2018-01-15      79.0      10.0      82.0      75.0      81.0     4.0
# 2018-01-16      51.0       9.0       5.0       9.0      32.0     5.0
# 2018-01-17       6.0      48.0       NaN       NaN      80.0     6.0
# 2018-01-18      37.0       3.0       NaN       NaN      32.0     7.0
# 2018-01-19       8.0      21.0      97.0      84.0      25.0     8.0
# 2018-01-20      98.0      73.0      36.0      90.0      50.0     9.0
#
#                   Date
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
# 2018-01-06         NaN
# 2018-01-07         NaN
# 2018-01-08         NaN
# 2018-01-09         NaN
# 2018-01-10         NaN
# 2018-01-11   January 1
# 2018-01-12   January 2
# 2018-01-13   January 3
# 2018-01-14   January 4
# 2018-01-15   January 5
# 2018-01-16   January 6
# 2018-01-17   January 7
# 2018-01-18   January 8
# 2018-01-19   January 9
# 2018-01-20  January 10

# %%
# Count the number of ocurrencies at the specified column
df['Random 1'].value_counts()
# Out:
# 24    2
# 72    2
# 79    2
# 63    1
# 41    1
# 97    1
# 98    1
# 37    1
# 6     1
# 8     1
# 33    1
# 77    1
# 62    1
# 51    1
# 29    1
# 61    1
# 64    1
# Name: Random 1, dtype: int64

# %%
# Change the string column to uppercase
df['Date'].str.upper()
# Out:
# 2018-01-01     JANUARY 1
# 2018-01-02     JANUARY 2
# 2018-01-03     JANUARY 3
# 2018-01-04     JANUARY 4
# 2018-01-05     JANUARY 5
# 2018-01-06     JANUARY 6
# 2018-01-07     JANUARY 7
# 2018-01-08     JANUARY 8
# 2018-01-09     JANUARY 9
# 2018-01-10    JANUARY 10
# 2018-01-11    JANUARY 11
# 2018-01-12    JANUARY 12
# 2018-01-13    JANUARY 13
# 2018-01-14    JANUARY 14
# 2018-01-15    JANUARY 15
# 2018-01-16    JANUARY 16
# 2018-01-17    JANUARY 17
# 2018-01-18    JANUARY 18
# 2018-01-19    JANUARY 19
# 2018-01-20    JANUARY 20
# Freq: D, Name: Date, dtype: object

# %%
# Create a list of dataframes based on the previous one
df_temp = [df[:5], df[7:10]]

# %%
# Check the list of Dataframes
df_temp
# Out:
# [            Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
#  2018-01-01        77        51      54.0      37.0        90       0
#  2018-01-02        79        36      69.0      64.0        89       1
#  2018-01-03        24        70       NaN       NaN        80       2
#  2018-01-04        41        23      20.0      96.0        35       3
#  2018-01-05        79        10      82.0      75.0        81       4
#
#                   Date
#  2018-01-01  January 1
#  2018-01-02  January 2
#  2018-01-03  January 3
#  2018-01-04  January 4
#  2018-01-05  January 5  ,
#              Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
#  2018-01-08        37         3       NaN       NaN        32       7
#  2018-01-09         8        21      97.0      84.0        25       8
#  2018-01-10        98        73      36.0      90.0        50       9
#
#                    Date
#  2018-01-08   January 8
#  2018-01-09   January 9
#  2018-01-10  January 10  ]

# %%
# Concatenate the list of Dataframes
pd.concat(df_temp)
# Out:
#             Random 1  Random 2  Random 3  Random 4  Random 5  Arange  \
# 2018-01-01        77        51      54.0      37.0        90       0
# 2018-01-02        79        36      69.0      64.0        89       1
# 2018-01-03        24        70       NaN       NaN        80       2
# 2018-01-04        41        23      20.0      96.0        35       3
# 2018-01-05        79        10      82.0      75.0        81       4
# 2018-01-08        37         3       NaN       NaN        32       7
# 2018-01-09         8        21      97.0      84.0        25       8
# 2018-01-10        98        73      36.0      90.0        50       9
#
#                   Date
# 2018-01-01   January 1
# 2018-01-02   January 2
# 2018-01-03   January 3
# 2018-01-04   January 4
# 2018-01-05   January 5
# 2018-01-08   January 8
# 2018-01-09   January 9
# 2018-01-10  January 10

# %%
# Create a Dataframe
left = pd.DataFrame({'date': pd.date_range('20180101', periods=2), 'left': [912.88, 444.11]})

# %%
# Check Dataframe's contents
left.head()
# Out:
#         date    left
# 0 2018-01-01  912.88
# 1 2018-01-02  444.11

# %%
# Create a Dataframe to be joined with the previous one
right = pd.DataFrame({'date': pd.date_range('20180101', periods=2), 'right': [101.15, 662.38]})

# %%
# Check Dataframe's contents
right.head()
# Out:
#         date   right
# 0 2018-01-01  101.15
# 1 2018-01-02  662.38

# %%
# Join two Dataframes
pd.merge(left, right, on='date')
# Out:
#         date    left   right
# 0 2018-01-01  912.88  101.15
# 1 2018-01-02  444.11  662.38

# %%
# Create a new Dataframe
df_1 = pd.DataFrame(np.random.randint(0, 20, size=(10, 2)), columns=['Random 1', 'Random 2'])

# %%
# Check Dataframe's contents
df_1.head()
# Out:
#    Random 1  Random 2
# 0         3        16
# 1        11         3
# 2         0         1
# 3         5        18
# 4        15         3

# %%
# Create a new Dataframe to be appended to the previous one
df_2 = pd.DataFrame(np.random.randint(0, 10, size=(5, 2)), columns=['Random 1', 'Random 2'])

# %%
# Check Dataframe's contents
df_2.head()
# Out:
#    Random 1  Random 2
# 0         0         0
# 1         8         3
# 2         4         8
# 3         0         6
# 4         8         5

# %%
# Append the second Dataframe to the first. Ignore index will fix duplicate indexes
df_1.append(df_2, ignore_index=True)
# Out:
#     Random 1  Random 2
# 0          3        16
# 1         11         3
# 2          0         1
# 3          5        18
# 4         15         3
# 5         10         9
# 6          8         2
# 7         10        14
# 8         18        19
# 9          5        10
# 10         0         0
# 11         8         3
# 12         4         8
# 13         0         6
# 14         8         5

# %%
# Group by column
df.groupby('Random 2').sum()
# Out:
#           Random 1  Random 3  Random 4  Random 5  Arange
# Random 2
# 3               37       NaN       NaN        32       7
# 5               61       4.0      15.0        15      12
# 9               51       5.0       9.0        32       5
# 10              79      82.0      75.0        81       4
# 19              97      85.0      93.0        43      18
# 21               8      97.0      84.0        25       8
# 23              41      20.0      96.0        35       3
# 36              79      69.0      64.0        89       1
# 37              62      82.0      75.0        76      13
# 48               6       NaN       NaN        80       6
# 51              77      54.0      37.0        90       0
# 70              24       NaN       NaN        80       2
# 71              33      75.0      97.0        23      19
# 73              98      36.0      90.0        50       9
# 80              24      12.0      64.0        62      16
# 81              72      23.0      11.0        63      15
# 82              72      97.0      75.0        13      10
# 86              64      94.0      41.0        22      17
# 87              63      14.0      45.0        63      11
# 90              29      39.0      55.0        47      14

# %%
# Group by multiple columns
df.groupby(['Random 3', 'Random 4']).sum()
# Out:
#                    Random 1  Random 2  Random 5  Arange
# Random 3 Random 4
# 4.0      15.0            61         5        15      12
# 5.0      9.0             51         9        32       5
# 12.0     64.0            24        80        62      16
# 14.0     45.0            63        87        63      11
# 20.0     96.0            41        23        35       3
# 23.0     11.0            72        81        63      15
# 36.0     90.0            98        73        50       9
# 39.0     55.0            29        90        47      14
# 54.0     37.0            77        51        90       0
# 69.0     64.0            79        36        89       1
# 75.0     97.0            33        71        23      19
# 82.0     75.0           141        47       157      17
# 85.0     93.0            97        19        43      18
# 94.0     41.0            64        86        22      17
# 97.0     75.0            72        82        13      10
#          84.0             8        21        25       8

# %%
# Stack a Dataframe. The result is a Series object
df.stack()
# Out:
# 2018-01-01  Random 1            77
#             Random 2            51
#             Random 3            54
#             Random 4            37
#             Random 5            90
#             Arange               0
#             Date         January 1
# 2018-01-02  Random 1            79
#             Random 2            36
#             Random 3            69
#             Random 4            64
#             Random 5            89
#             Arange               1
#             Date         January 2
# 2018-01-03  Random 1            24
#             Random 2            70
#             Random 5            80
#             Arange               2
#             Date         January 3
# 2018-01-04  Random 1            41
#             Random 2            23
#             Random 3            20
#             Random 4            96
#             Random 5            35
#             Arange               3
#             Date         January 4
# 2018-01-05  Random 1            79
#             Random 2            10
#             Random 3            82
#             Random 4            75
#                            ...
# 2018-01-16  Arange              15
#             Date        January 16
# 2018-01-17  Random 1            24
#             Random 2            80
#             Random 3            12
#             Random 4            64
#             Random 5            62
#             Arange              16
#             Date        January 17
# 2018-01-18  Random 1            64
#             Random 2            86
#             Random 3            94
#             Random 4            41
#             Random 5            22
#             Arange              17
#             Date        January 18
# 2018-01-19  Random 1            97
#             Random 2            19
#             Random 3            85
#             Random 4            93
#             Random 5            43
#             Arange              18
#             Date        January 19
# 2018-01-20  Random 1            33
#             Random 2            71
#             Random 3            75
#             Random 4            97
#             Random 5            23
#             Arange              19
#             Date        January 20
# Length: 134, dtype: object

# %%
# Unstack a Dataframe.
df.unstack()
# Out:
# Random 1  2018-01-01            77
#           2018-01-02            79
#           2018-01-03            24
#           2018-01-04            41
#           2018-01-05            79
#           2018-01-06            51
#           2018-01-07             6
#           2018-01-08            37
#           2018-01-09             8
#           2018-01-10            98
#           2018-01-11            72
#           2018-01-12            63
#           2018-01-13            61
#           2018-01-14            62
#           2018-01-15            29
#           2018-01-16            72
#           2018-01-17            24
#           2018-01-18            64
#           2018-01-19            97
#           2018-01-20            33
# Random 2  2018-01-01            51
#           2018-01-02            36
#           2018-01-03            70
#           2018-01-04            23
#           2018-01-05            10
#           2018-01-06             9
#           2018-01-07            48
#           2018-01-08             3
#           2018-01-09            21
#           2018-01-10            73
#                            ...
# Arange    2018-01-11            10
#           2018-01-12            11
#           2018-01-13            12
#           2018-01-14            13
#           2018-01-15            14
#           2018-01-16            15
#           2018-01-17            16
#           2018-01-18            17
#           2018-01-19            18
#           2018-01-20            19
# Date      2018-01-01     January 1
#           2018-01-02     January 2
#           2018-01-03     January 3
#           2018-01-04     January 4
#           2018-01-05     January 5
#           2018-01-06     January 6
#           2018-01-07     January 7
#           2018-01-08     January 8
#           2018-01-09     January 9
#           2018-01-10    January 10
#           2018-01-11    January 11
#           2018-01-12    January 12
#           2018-01-13    January 13
#           2018-01-14    January 14
#           2018-01-15    January 15
#           2018-01-16    January 16
#           2018-01-17    January 17
#           2018-01-18    January 18
#           2018-01-19    January 19
#           2018-01-20    January 20
# Length: 140, dtype: object

# %%
# Create a pivot table based on a DataFrame
pd.pivot_table(df, values=['Random 1', 'Random 2', 'Random 3', 'Random 4', 'Random 5'], columns='Date').head()
# Out:
# Date      January 1  January 10  January 11  January 12  January 13  \
# Random 1       77.0        98.0        72.0        63.0        61.0
# Random 2       51.0        73.0        82.0        87.0         5.0
# Random 3       54.0        36.0        97.0        14.0         4.0
# Random 4       37.0        90.0        75.0        45.0        15.0
# Random 5       90.0        50.0        13.0        63.0        15.0
#
# Date      January 14  January 15  January 16  January 17  January 18  \
# Random 1        62.0        29.0        72.0        24.0        64.0
# Random 2        37.0        90.0        81.0        80.0        86.0
# Random 3        82.0        39.0        23.0        12.0        94.0
# Random 4        75.0        55.0        11.0        64.0        41.0
# Random 5        76.0        47.0        63.0        62.0        22.0
#
# Date      January 19  January 2  January 20  January 3  January 4  January 5  \
# Random 1        97.0       79.0        33.0       24.0       41.0       79.0
# Random 2        19.0       36.0        71.0       70.0       23.0       10.0
# Random 3        85.0       69.0        75.0        NaN       20.0       82.0
# Random 4        93.0       64.0        97.0        NaN       96.0       75.0
# Random 5        43.0       89.0        23.0       80.0       35.0       81.0
#
# Date      January 6  January 7  January 8  January 9
# Random 1       51.0        6.0       37.0        8.0
# Random 2        9.0       48.0        3.0       21.0
# Random 3        5.0        NaN        NaN       97.0
# Random 4        9.0        NaN        NaN       84.0
# Random 5       32.0       80.0       32.0       25.0

# %%
# Create a new figure object
plt.figure()

# %%
# Plot the figure
df.plot()

# %%
# Export data to csv
df.to_csv('pandas_data.csv')
