# %% [markdown]
# # NLP Fundamentals II

# %% [markdown]
# This is a more in depth introduction to NLP. The examples are from the book http://www.nltk.org/book/

# %% [markdown]
# ## Imports

# %%
# Import all the examples from the nltk book library
from nltk.book import *
from nltk.corpus import gutenberg
from nltk.corpus import webtext
from nltk.corpus import nps_chat
from nltk.corpus import brown
from nltk.corpus import reuters
from nltk.corpus import inaugural
from nltk.corpus import udhr
from nltk.corpus import PlaintextCorpusReader
import nltk
import numpy as np
import matplotlib.pyplot as plt
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Set inline plots
# %matplotlib inline

# %% [markdown]
# ## Content analysis

# %%
# Check the information stored on the variable text1
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
# Check the concordance of the word "monstrous" in the book "Moby Dick"

'''
The first time that this code runs, an index will be built for subsequent searches on this text
'''
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
# Find the time that people lived on the Book of Genesis
text3.concordance('lived')
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
# Look for similar words based in the context for monstrous in Moby Dick and Sense and Sensibility

'''
In the second text, monstrous is a word used together with good adjectives and words, somehow intensifying the
meaning of these other words
'''
text1.similar('monstrous')
print('\n')
text2.similar('monstrous')
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
#
#
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
# List common contexts between two words
text2.common_contexts(['monstrous', 'very'])
print('\n')
text1.common_contexts(['monstrous', 'fearless'])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad
#
#
# most_and

# %%
# Display the location of words throughout the text using a disperson plot
text4.dispersion_plot(['citizen', 'democracy', 'freedom', 'duties', 'America'])

# %%
# Count the number of words (punctuation included) in the Book of Genesis

'''
In NLP, each word or punctuation is called a token, so there are 44764 tokens in the Book of Genesis. A token can be
defined as a sequence of characters.
'''
len(text3)
# Out:
# 44764

# %%
# Sort the unique tokens in the Book of Genesis

'''Punctuation and capitalized words precede lowercase words.'''
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
# Count the unique tokens in the Book of Genesis

'''This book has 2789 word types, which are unique ocurrencies of sentences in a text. Punctuation symbols are
called types.'''
len(set(text3))
# Out:
# 2789

# %%
# Calculate the lexical richeness and the average word usage frequency of the Book of Genesis

'''Around 6% of the text is comprised of unique words and each word is used 16 times an average. The following
are two ways to get to the same conclusion.'''
print(len(set(text3)) / len(text3))
print(len(text3) / len(set(text3)))
# Out:
# 0.06230453042623537
# 16.050197203298673

# %%
# Count the number of times a given word is used throughout the text
text3.count('smote')
# Out:
# 5

# %%
# Calculate the proportion of the text that is composed of a single word
text1.count('a') / len(text1)
# Out:
# 0.017517895552087846

# %%
# Define functions to automate word count and proportion calculation tasks
def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(count, total):
    return 100 * count / total

def average_words(text):
    return len(text) / len(set(text))

# %%
# Test the functions
print('Lexical diversity (Moby Dick): {0}'.format(lexical_diversity(text1)))
print('Lexical diversity (Sense and Sensibility): {0}'.format(lexical_diversity(text2)))

print('Average words (Moby Dick): {0}'.format(average_words(text1)))
print('Percentage (Moby Dick): {0}'.format(percentage(text1.count('monstrous'), len(text1))))
# Out:
# Lexical diversity (Moby Dick): 0.07406285585022564
# Lexical diversity (Sense and Sensibility): 0.04826383002768831
# Average words (Moby Dick): 13.502044830977896
# Percentage (Moby Dick): 0.003834076505162584

# %%
# Inspect the first sentences of texts
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
# Show the most frequent tokens in a document
fdist1 = FreqDist(text1)
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
# Show the total number of tokens and plot the most frequent tokens in the book

'''
Almost half of the first book is composed of words that bring no meaning to its subject.
'''
print(fdist1)
plt.figure(figsize=(12, 6))
fdist1.plot(50, cumulative=True)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
# Print words that occur only once in the document, or hapaxes

'''
Due to the lack of context its hard to guess what the subject of the book might be.
'''
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
# Filter words with more than 15 characters to see if they can explain the subject of the book

'''
These words aren't different from the previous hapaxes, they can also be considered as such and hardly explain what
this text is about.
'''
V = set(text1)
long_words = [w for w in V if len(w) > 15]
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
# Filter the words with more than seven characters and that occur seven or more times in the text
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
# Get collocations in the text, which are sequences of words that walk together throughout the text

'''
The collocations() method return bigrams, which are pairs of words
'''
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
# Get the distribution of word lengths throughout the text
fdist = FreqDist(len(w) for w in text1)
print(fdist)
fdist
# Out:
# <FreqDist with 19 samples and 260819 outcomes>
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
# Check the most common word lengths
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
# Working with corpora (large bodies of text). Check the titles available at the Gutenberg project
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# Count the number of words in the first text
emma = gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
# Check the concordance of a word throughout the book
emma = nltk.Text(emma)
emma.concordance('surprise')
# Out:
# Displaying 1 of 1 matches:
#  that Emma could not but feel some surprise , and a little displeasure , on he

# %%
# Display statistics for each book available in the Gutenberg project
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print(fileid, 'AVG word length: {0}.'.format(round(num_chars / num_words)), 'AVG sentence length: {0}'.format(round(num_words / num_sents)), 'AVG word usage: {0}'.format(round(num_words / num_vocab)))
# Out:
# austen-emma.txt AVG word length: 5. AVG sentence length: 25 AVG word usage: 26
# austen-persuasion.txt AVG word length: 5. AVG sentence length: 26 AVG word usage: 17
# austen-sense.txt AVG word length: 5. AVG sentence length: 28 AVG word usage: 22
# bible-kjv.txt AVG word length: 4. AVG sentence length: 34 AVG word usage: 79
# blake-poems.txt AVG word length: 5. AVG sentence length: 19 AVG word usage: 5
# bryant-stories.txt AVG word length: 4. AVG sentence length: 19 AVG word usage: 14
# burgess-busterbrown.txt AVG word length: 4. AVG sentence length: 18 AVG word usage: 12
# carroll-alice.txt AVG word length: 4. AVG sentence length: 20 AVG word usage: 13
# chesterton-ball.txt AVG word length: 5. AVG sentence length: 20 AVG word usage: 12
# chesterton-brown.txt AVG word length: 5. AVG sentence length: 23 AVG word usage: 11
# chesterton-thursday.txt AVG word length: 5. AVG sentence length: 18 AVG word usage: 11
# ...

# %%
# Print the available files scrapped from the web and available in the NLTK library
for fileid in webtext.fileids():
    print(fileid, webtext.raw(fileid)[:65], '...')
# Out:
# firefox.txt Cookie Manager: "Don't allow sites that set removed cookies to se ...
# grail.txt SCENE 1: [wind] [clop clop clop]
# KING ARTHUR: Whoa there!  [clop ...
# overheard.txt White guy: So, do you have any plans for this evening?
# Asian girl ...
# pirates.txt PIRATES OF THE CARRIBEAN: DEAD MAN'S CHEST, by Ted Elliott & Terr ...
# singles.txt 25 SEXY MALE, seeks attrac older single lady, for discreet encoun ...
# wine.txt Lovely delicate, fragrant Rhone wine. Polished leather and strawb ...

# %%
# Inspect chat data available in the NLTK library
chatroom = nps_chat.posts('10-19-20s_706posts.xml')
chatroom[123]
# Out:
# ['i',
#  'do',
#  "n't",
#  'want',
#  'hot',
#  'pics',
#  'of',
#  'a',
#  'female',
#  ',',
#  'I',
#  'can',
#  'look',
#  'in',
#  'a',
#  'mirror',
#  '.']

# %%
# Describe the genres available in the Brown corpus
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
# Inspect the occurencies of given words in the Brown corpus
news_text = brown.words(categories='news')
fdist = nltk.FreqDist(w.lower() for w in news_text)
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
    print(m + ':', fdist[m], end=' ')
# Out:
# can: 94 could: 87 may: 93 might: 38 must: 53 will: 389

# %%
# Inspect the stylistics of the genres available in the Brown corpus

'''
The counts for each modal are displayed by genre in a table. CFD stands for Conditional Frequency Distribution.
'''
cfd = nltk.ConditionalFreqDist((genre, word) for genre in brown.categories() for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %%
# Inspect Reuters fileids

'''
These are divided into training and test sets for machine learning applications.
'''
reuters.fileids()
# Out:
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843',
#  'test/14844',
#  'test/14849',
#  'test/14852',
#  'test/14854',
#  'test/14858',
#  'test/14859',
#  'test/14860',
#  'test/14861',
#  'test/14862',
#  'test/14863',
#  'test/14865',
#  'test/14867',
#  'test/14872',
#  'test/14873',
#  'test/14875',
#  'test/14876',
#  'test/14877',
#  'test/14881',
#  'test/14882',
#  'test/14885',
#  'test/14886',
#  'test/14888',
#  'test/14890',
#  'test/14891',
#  'test/14892',
#  'test/14899',
#  'test/14900',
#  'test/14903',
#  'test/14904',
#  'test/14907',
#  'test/14909',
#  'test/14911',
#  'test/14912',
#  'test/14913',
#  'test/14918',
#  'test/14919',
#  'test/14921',
#  'test/14922',
#  'test/14923',
#  'test/14926',
#  'test/14928',
#  'test/14930',
#  'test/14931',
#  'test/14932',
#  'test/14933',
#  'test/14934',
#  'test/14941',
#  'test/14943',
# ...

# %%
# Inspect Reuters categories
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
# ...

# %%
# Check fileids associated with some categories

'''
In the Reuters corpus, documents can have more than one category.
'''
reuters.fileids('barley')
# Out:
# ['test/15618',
#  'test/15649',
#  'test/15676',
#  'test/15728',
#  'test/15871',
#  'test/15875',
#  'test/15952',
#  'test/17767',
#  'test/17769',
#  'test/18024',
#  'test/18263',
#  'test/18908',
#  'test/19275',
#  'test/19668',
#  'training/10175',
#  'training/1067',
#  'training/11208',
#  'training/11316',
#  'training/11885',
#  'training/12428',
#  'training/13099',
#  'training/13744',
#  'training/13795',
#  'training/13852',
#  'training/13856',
#  'training/1652',
#  'training/1970',
#  'training/2044',
#  'training/2171',
#  'training/2172',
#  'training/2191',
#  'training/2217',
#  'training/2232',
#  'training/3132',
#  'training/3324',
#  'training/395',
#  'training/4280',
#  'training/4296',
#  'training/5',
#  'training/501',
#  'training/5467',
#  'training/5610',
#  'training/5640',
#  'training/6626',
#  'training/7205',
#  'training/7579',
#  'training/8213',
#  'training/8257',
#  'training/8759',
#  'training/9865',
#  'training/9958']

# %%
# Check sentences within some categories

'''
Uppercase words are titles, stored in this way for convenience.
'''
reuters.sents(categories=['lumber', 'livestock'])
# Out:
# [['INDONESIAN', 'COMMODITY', 'EXCHANGE', 'MAY', 'EXPAND', 'The', 'Indonesian', 'Commodity', 'Exchange', 'is', 'likely', 'to', 'start', 'trading', 'in', 'at', 'least', 'one', 'new', 'commodity', ',', 'and', 'possibly', 'two', ',', 'during', 'calendar', '1987', ',', 'exchange', 'chairman', 'Paian', 'Nainggolan', 'said', '.'], ['He', 'told', 'Reuters', 'in', 'a', 'telephone', 'interview', 'that', 'trading', 'in', 'palm', 'oil', ',', 'sawn', 'timber', ',', 'pepper', 'or', 'tobacco', 'was', 'being', 'considered', '.'], ...]

# %%
# Check the properties of the Inaugural Address corpus
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
# Print the years in the filenames
[fileid[:4] for fileid in inaugural.fileids()]
# Out:
# ['1789',
#  '1793',
#  '1797',
#  '1801',
#  '1805',
#  '1809',
#  '1813',
#  '1817',
#  '1821',
#  '1825',
#  '1829',
#  '1833',
#  '1837',
#  '1841',
#  '1845',
#  '1849',
#  '1853',
#  '1857',
#  '1861',
#  '1865',
#  '1869',
#  '1873',
#  '1877',
#  '1881',
#  '1885',
#  '1889',
#  '1893',
#  '1897',
#  '1901',
#  '1905',
#  '1909',
#  '1913',
#  '1917',
#  '1921',
#  '1925',
#  '1929',
#  '1933',
#  '1937',
#  '1941',
#  '1945',
#  '1949',
#  '1953',
#  '1957',
#  '1961',
#  '1965',
#  '1969',
#  '1973',
#  '1977',
#  '1981',
#  '1985',
#  '1989',
#  '1993',
#  '1997',
#  '2001',
#  '2005',
#  '2009']

# %%
# Describe the usage of words 'America' and 'Citizen' over time
cfd = nltk.ConditionalFreqDist((target, fileid[:4]) for fileid in inaugural.fileids() for w in inaugural.words(fileid) for target in ['america', 'citizen'] if w.lower().startswith(target))
plt.figure(figsize=(12, 6))
cfd.plot()

# %%
# Check the available files and languages in the Universal Declaration of Human Rights
udhr.fileids()
# Out:
# ['Abkhaz-Cyrillic+Abkh',
#  'Abkhaz-UTF8',
#  'Achehnese-Latin1',
#  'Achuar-Shiwiar-Latin1',
#  'Adja-UTF8',
#  'Afaan_Oromo_Oromiffa-Latin1',
#  'Afrikaans-Latin1',
#  'Aguaruna-Latin1',
#  'Akuapem_Twi-UTF8',
#  'Albanian_Shqip-Latin1',
#  'Amahuaca',
#  'Amahuaca-Latin1',
#  'Amarakaeri-Latin1',
#  'Amuesha-Yanesha-UTF8',
#  'Arabela-Latin1',
#  'Arabic_Alarabia-Arabic',
#  'Asante-UTF8',
#  'Ashaninca-Latin1',
#  'Asheninca-Latin1',
#  'Asturian_Bable-Latin1',
#  'Aymara-Latin1',
#  'Balinese-Latin1',
#  'Bambara-UTF8',
#  'Baoule-UTF8',
#  'Basque_Euskara-Latin1',
#  'Batonu_Bariba-UTF8',
#  'Belorus_Belaruski-Cyrillic',
#  'Belorus_Belaruski-UTF8',
#  'Bemba-Latin1',
#  'Bengali-UTF8',
#  'Beti-UTF8',
#  'Bichelamar-Latin1',
#  'Bikol_Bicolano-Latin1',
#  'Bora-Latin1',
#  'Bosnian_Bosanski-Cyrillic',
#  'Bosnian_Bosanski-Latin2',
#  'Bosnian_Bosanski-UTF8',
#  'Breton-Latin1',
#  'Bugisnese-Latin1',
#  'Bulgarian_Balgarski-Cyrillic',
#  'Bulgarian_Balgarski-UTF8',
# ...

# %%
# Plot a cumulative frequency distribution for word lengths across languages
languages = ['Portuguese_Portugues', 'Chickasaw', 'English', 'German_Deutsch', 'Greenlandic_Inuktikut', 'Hungarian_Magyar', 'Ibibio_Efik']
cfd = nltk.ConditionalFreqDist((lang, len(word)) for lang in languages for word in udhr.words(lang + '-Latin1'))
plt.figure(figsize=(12, 6))
cfd.plot(cumulative=True)

# %%
# Load a custom corpus
corpus_root = '/home/henrique/Documents/Projetos/notebooks/projects/data/nlp_fundamentals/'
wordlists = PlaintextCorpusReader(corpus_root, 'asa-branca.txt')
wordlists.fileids()
# Out:
# ['asa-branca.txt']

# %%
# Check its words
wordlists.words()
# Out:
# ['Luiz', 'Gonzaga', '-', 'Asa', 'Branca', 'Quando', ...]

# %%
fdist = FreqDist(wordlists.words())
fdist.most_common(10)
# Out:
# [(',', 10),
#  ('meu', 8),
#  ('a', 6),
#  ('de', 6),
#  ('Eu', 4),
#  ('Por', 4),
#  ('eu', 4),
#  ('coração', 4),
#  ('não', 4),
#  ('viu', 4)]

# %%
plt.figure(figsize=(12, 6))
fdist.plot(30, cumulative=True)

# %%
# Print the proportion of each word type inside the text
[wordlists.words().count(w) / len(wordlists.words()) for w in set(wordlists.words())]
# Out:
# [0.011363636363636364,
#  0.011363636363636364,
#  0.045454545454545456,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.017045454545454544,
#  0.03409090909090909,
#  0.017045454545454544,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.011363636363636364,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.022727272727272728,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.011363636363636364,
#  0.005681818181818182,
#  0.005681818181818182,
#  0.011363636363636364,
#  0.005681818181818182,
# ...

# %%
# Create a basic model to predict which word will be the next to one provided
def generate_model(cfdist, word, num=15):
    for i in range(num):
        print(word, end= ' ')
        word = cfdist[word].max()
        
text = nltk.corpus.genesis.words('english-kjv.txt')
bigrams = nltk.bigrams(text)
cfd = nltk.ConditionalFreqDist(bigrams)

# %%
# Inspect the generated bigrams
cfd['living']
# Out:
# FreqDist({',': 1,
#           '.': 1,
#           'creature': 7,
#           'soul': 1,
#           'substance': 2,
#           'thing': 4})

# %%
# Generate a model
generate_model(cfd, 'living')
# Out:
# living creature that he said , and the land of the land of the land
